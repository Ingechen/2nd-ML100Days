# %% [markdown]
# 作業ㄧ：
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
# <li>1.你選的這組資料為何重要<li>
# CareerCon 2019 - Help Navigate Robots
# 在研發機器人時，讓機器人了解所處環境是非常重要的，如此一來機器人可以知道他們要如何行走才能走得更穩。
# <li>2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)<li>
# Department of Signal Processing and Department of Automation and Mechanical Engineering, Tampere University, Finland
# <li>3. 蒐集而來的資料型態為何<li>
# 此檔案資料型態都是數值類型。
# <li>4. 這組資料想解決的問題如何評估<li>
# Multiclass Accuracy = the average number of observations with the correct label.

# %% [markdown]
# 作業二：
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
# <li>1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)<li>
# 核心問題就是如何透過大數據分析更精準掌握客戶，比如可以利用載客資料（載客地點、年齡、時間、天氣、抵達地點等），可能便可以發現其中一些變數當中會有關聯，例如早上8點時台北車站附近載客需求大，可能是因為上班族都要趕著上班。因此若能掌握關鍵變數與載客需求的關聯，便可以藉此將車隊在特定時間地點排班，能更有效率載客。
# <li>2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)<li>
# 可以將車隊所有車輛裝載追蹤系統，將載客時間、上下車地點以及車資，也能將車輛裝載行車記錄器，將載客路線紀錄起來。
# <li>3. 蒐集而來的資料型態為何<li>
# 可以將大部分資料以數值、時間、類別等型態紀錄。
# <li>4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)<li>
# 假設利用預測模型發現某個地點在特定時間時載客需求大，便可以透過系統通知司機，當司機抵達該地點附近時，評估這位司機在接下來半小時內在這附近接到乘客的機率。

# %% [markdown]
# 作業三
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
def mean_squared_error(y,yp):
    """
    計算MSE
    Args:
        -y: 實際值
        -yp: 預測值
    Return:
        -mse: MSE
    請完成這個 Function 後往下執行
    """
    mse=MSE=sum((y-yp)**2)/len(y)
    return mse

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 191.529
# The Mean absolute error is 11.297
